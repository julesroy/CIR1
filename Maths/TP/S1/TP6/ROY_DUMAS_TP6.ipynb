# %% [markdown]
# # TP 6 - Limites et DL

# %% [markdown]
# Consignes :
#
# - Renommer ce fichier <b>nom1-nom2-TP6</b> , en cliquant sur le titre du fichier "TP 6 - Limites et DL" en haut à gauche
# - <u>TP à rendre dans le devoir Teams à la fin de la séance</u>.
# - TP à faire par groupes de 2. Le groupe de travail sera le même pour toute l'année.
#
#
#   Cliquer deux fois sur la cellule pour completer ci-dessous :
#
# - NOM PRENOM : ROY Jules
# - NOM PRENOM : DUMAS Antonin

# %% [markdown]
# #  Limites et DL

# %% [markdown]
# Consultez la documentation (`help(limits)`) pour les limites ou le <a href="https://www.sagemath.org/calctut/limits.html">tutorial</a>
#
# Pour les développements limités voir `help(taylor)` pour la partie régulière et la commande  <a href="http://doc.sagemath.org/html/en/reference/calculus/sage/symbolic/series.html">series</a> pour le développement complet.

# %% [markdown]
# # EXERCICE 1

# %% [markdown]
# a) Calculer les limites suivantes :
# $$i)\quad \lim_{x\rightarrow 0} \ \dfrac{\ln(1+x^3)(e^{x^2}-1)}{\sin^3(x)(1-\cos(x))} \quad \text{ et }\quad \text{$ ii)$} \quad \lim_{x \rightarrow +\infty} \ \sqrt{x^2+x+1}$$

# %%
#i
x = var('x') #définition de la variable x
calc = limit((ln(1 + (x^3)) * (exp(x^2) - 1) )/(sin(x)^3 * (1 - cos(x))), x = 0) #on calcule la limte de la fonction quand x tend vers 0
show(calc) #on affiche le résultat
# Out:
# 2

# %%
#ii
x = var('x') #définition de la variable x
calc = limit(sqrt((x^2) + x + 1), x = +infinity) #on calcule la limte de la fonction quand x tend vers + l'infini (+infinity)
show(calc) #on affiche le résultat
# Out:
# +Infinity

# %% [markdown]
# b) Vérifier la valeur de la limite $ a)$ et $b)$ graphiquement en traçant les courbes correspondantes.

# %%
#fonction (i)
print("On remarque que la limite quand x tend vers 0 est égale à 2")
plot((ln(1 + (x^3)) * (exp(x^2) - 1) )/(sin(x)^3 * (1 - cos(x))), x, -0.2, 0.2) #on trace la courbe de la fonction sur l'intervalle [-0.2,0.2] pour visualiser la limite de la fonction quand x tend vers 0
# Out:
# On remarque que la limite quand x tend vers 0 est égale à 2
# Graphics object consisting of 1 graphics primitive

# %%
#fonction (ii)
print("On remarque que la limite quand x tend vers + l'infini est égale à + l'infini")
plot(sqrt((x^2) + x + 1), x, -1, 10) #on trace la courbe de la fonction sur l'intervalle [-1,10] pour visualiser la limite de la fonction quand x tend vers + l'infini
# Out:
# On remarque que la limite quand x tend vers + l'infini est égale à + l'infini
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# # EXERCICE 2

# %% [markdown]
# a) Calculer $$\lim_{x\rightarrow \pi} \ \bigg(\dfrac{1}{x^2}-\dfrac{1}{\sin^2 x}\bigg)$$

# %%
x = var('x') # je definis x une variable
f(x)=(1/x**2)-(1/sin(x)**2) # je definis f(x)
limit(f(x),x=pi) # je calcul la limite de f(x)
# Out:
# -Infinity

# %% [markdown]
# b) Dessiner le graphe de la fonction sur l'intervalle $(-4\pi,4\pi)$.

# %%
p = plot(f(x), x, -4*pi, 4*pi) #je definis p une courbe qui represente la fonction f(x) pour x ⊆[-4*pi, 4*pi]
p.show() # affichage de p
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# c) Dessiner le graphe de la fonction sur l'intervalle $(-4\pi,4\pi)$ en imposant une valeur minimale pour l'axe des ordonnées.

# %%
p = plot(f(x), x, -4*pi, 4*pi)
p.show(ymin=-10, ymax=0)# affichage de p avec l'axe des ordonnées de 0 a 10
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# d) Pour quelles autres valeurs de $x$ la fonction a la même limite obtenue en $a)$ ?

# %%
x = var('x')
f(x)=(1/x**2)-(1/sin(x)**2)
for x in range(-4*pi,4*pi,0.00001):
    if(f(x)==(Infinity)):
        print(f(x),"/")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression._integer_ (build/cythonized/sage/symbolic/expression.cpp:8627)()
#    1124         try:
# -> 1125             n = self.pyobject()
#    1126         except TypeError:
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.pyobject (build/cythonized/sage/symbolic/expression.cpp:6025)()
#     428         if not is_a_numeric(self._gobj):
# --> 429             raise TypeError("self must be a numeric expression")
#     430         return py_object_from_numeric(self._gobj)
#
# TypeError: self must be a numeric expression
#
# During handling of the above exception, another exception occurred:
#
# ...

# %% [markdown]
# # EXERCICE 3

# %% [markdown]
# a) Tracer sur le même graphe avec differentes couleurs et une legende, les fonctions $$x\mapsto x, \sin(x),\ln(x+1)$$
#
# En déduire le comportement de $\sin(x)$ et $\ln(x+1)$ par rapport à $x$ au voisinage de $0$.
#
# Vérifier vos déductions avec un calcul.

# %%
x = var('x')

a = plot((x), x, -10, 10,rgbcolor='blue',legend_label='x')# je definis ma courbe 
b = plot(sin(x), x, -10, 10,rgbcolor='black',legend_label='sin(x)')# je definis ma courbe 
c = plot(ln(x+1), x, -10, 10,rgbcolor='green',legend_label='ln(x+1)')# je definis ma courbe 
#d = text("Ce graphique represente les fonctions x en bleu, sin(x) en noir, ln(x+1) en vert")
s=a+b+c # je créé un graphique avec toute les courbes 
s.show()

print('Verification par calculs :')
print('sin(x) equivalent a x au voisinage de 0 donc x/x=1 donc sin(x)/x tend vers 1 en 0')
print('ln(x+1) equivalent a x au voisinage de 0 donc x/x=1 donc ln(x+1)/x tend vers 1 en 0')
# Out:
# verbose 0 (3797: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 90 points.
# verbose 0 (3797: plot.py, generate_plot_points) Last error message: 'can't convert complex to float'
# Graphics object consisting of 3 graphics primitives
# Verification par calculs :
# sin(x) equivalent a x au voisinage de 0 donc x/x=1 donc sin(x)/x tend vers 1 en 0
# ln(x+1) equivalent a x au voisinage de 0 donc x/x=1 donc ln(x+1)/x tend vers 1 en 0

# %% [markdown]
# b) Tracer sur le même graphe avec differentes couleurs et une legende, les fonctions $$x\mapsto x, x^2,\sqrt{x}$$
#
# En déduire la negligéabilité au voisinage de 0.
#
# Vérifier vos déductions avec un calcul.

# %%
x = var('x')
a = plot((x), x, -10, 10,rgbcolor='blue',legend_label='x') # je definis ma courbe 
b = plot((x**2), x, -10, 10,rgbcolor='black',legend_label='x**2')# je definis ma courbe 
c = plot((sqrt(x)), x, -10, 10,rgbcolor='green',legend_label='sqrt(x)')# je definis ma courbe 
s=a+b+c # je créé un graphique avec toute les courbes 
s.show() # j'affiche le graphique avec toute les courbes
# Out:
# verbose 0 (3797: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 100 points.
# verbose 0 (3797: plot.py, generate_plot_points) Last error message: 'math domain error'
# Graphics object consisting of 3 graphics primitives

# %%
print("x est o(sqrt(x)) au voisinage de 0")
print("x**2=o(x) au voisinage de 0")
print("x**2=o(sqrt(x)) au voisinage de 0")


print('Vérification par le calcul pour : x est o(sqrt(x)) au voisinage de 0')
limit(x/sqrt(x),x=0) # je calcul la limite de x/sqrt(x) si elle vaut 0 la negligéabilité est bonne.
# Out:
# x est o(sqrt(x)) au voisinage de 0
# x**2=o(x) au voisinage de 0
# x**2=o(sqrt(x)) au voisinage de 0
# Vérification par le calcul pour : x est o(sqrt(x)) au voisinage de 0
# 0

# %%
print('Vérification par le calcul pour : x**2=o(x) au voisinage de 0')
limit(x**2/x,x=0) # je calcul la limite de x**2/x si elle vaut 0 la negligéabilité est bonne.
# Out:
# Vérification par le calcul pour : x**2=o(x) au voisinage de 0
# 0

# %%
print('Vérification par le calcul pour : x**2=o(sqrt(x)) au voisinage de 0')
limit(x**2/sqrt(x),x=0) # je calcul la limite de x**2/sqrt(x) si elle vaut 0 la negligéabilité est bonne.
# Out:
# Vérification par le calcul pour : x**2=o(sqrt(x)) au voisinage de 0
# 0

# %% [markdown]
# c) Tracer sur le même graphe avec differentes couleurs et une legende, les fonctions $$x\mapsto x, \ln(x),e^x$$
#
# En déduire la negligéabilité au voisinage de $+\infty$.
#
# Vérifier vos déductions avec un calcul.

# %%
x = var('x')
a = plot((x), x, -10, 10,rgbcolor='blue',legend_label='x')
b = plot(ln(x), x, -10, 10,rgbcolor='black',legend_label='ln(x)')
c = plot(exp(x), x, -10, 10,rgbcolor='green',legend_label='exp(x)')
s=a+b+c
s.show(xmin=-10, xmax=10,ymin=-10, ymax=10)# a cause de la fonction exp(x) les courbes avaient des bornes tres grandes j'ai definis des bornes pour pouvoir distinctement les courbes
# Out:
# verbose 0 (3797: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 100 points.
# verbose 0 (3797: plot.py, generate_plot_points) Last error message: 'can't convert complex to float'
# Graphics object consisting of 3 graphics primitives

# %%
print("x=o(ln(x)) au voisinage de +infini")
print("x=o((exp(x))) au voisinage de +infini")
print("ln(x)=o((exp(x))) au voisinage de +infini")

print('Vérification par le calcul pour : x est o(ln(x)) au voisinage de +infini')
limit(ln(x)/x,x=+Infinity) # je calcul la limite de ln(x)/x si elle vaut 0 la negligéabilité est bonne.
# Out:
# x=o(ln(x)) au voisinage de +infini
# x=o((exp(x))) au voisinage de +infini
# ln(x)=o((exp(x))) au voisinage de +infini
# Vérification par le calcul pour : x est o(ln(x)) au voisinage de +infini
# 0

# %%
print('Vérification par le calcul pour : (exp(x)) est o(x) au voisinage de +infini')
limit(x/(exp(x)),x=+Infinity) # je calcul la limite de x/exp(x) si elle vaut 0 la negligéabilité est bonne.
# Out:
# Vérification par le calcul pour : (exp(x)) est o(x) au voisinage de +infini
# 0

# %%
print('Vérification par le calcul pour : exp(x) est o(ln(x)) au voisinage de +infini')
limit(ln(x)/(exp(x)),x=+Infinity) # je calcul la limite de ln(x)/exp(x) si elle vaut 0 la negligéabilité est bonne.
# Out:
# Vérification par le calcul pour : exp(x) est o(ln(x)) au voisinage de +infini
# 0

# %% [markdown]
# # EXERCICE 4

# %% [markdown]
# a) Donner un développement limité de $g(x)=\tan(x)$ en $x=0$ à l'ordre 1,2,3,4 et 5.
#
# Qu'est-ce que vous remarquez ?

# %%
x = var('x') #définition de la variable x
t = tan(x) #définition de tan(x) dans la variable t

#a l'ordre 1
print("DL à l'ordre 1:")
show(taylor(t,x,0,1)) #on utilise la fonction taylor de sagemath pour calculer le DL de tan(x) à l'ordre 1

#a l'ordre 2
print("DL à l'ordre 2:")
show(taylor(t,x,0,2)) #on utilise la fonction taylor de sagemath pour calculer le DL de tan(x) à l'ordre 2

#a l'ordre 3
print("DL à l'ordre 3:")
show(taylor(t,x,0,3)) #on utilise la fonction taylor de sagemath pour calculer le DL de tan(x) à l'ordre 3

#a l'ordre 4
print("DL à l'ordre 4:")
show(taylor(t,x,0,4)) #on utilise la fonction taylor de sagemath pour calculer le DL de tan(x) à l'ordre 4

#a l'ordre 5
print("DL à l'ordre 5:")
show(taylor(t,x,0,5)) #on utilise la fonction taylor de sagemath pour calculer le DL de tan(x) à l'ordre 5
# Out:
# DL à l'ordre 1:
# x
# DL à l'ordre 2:
# x
# DL à l'ordre 3:
# 1/3*x^3 + x
# DL à l'ordre 4:
# 1/3*x^3 + x
# DL à l'ordre 5:
# 2/15*x^5 + 1/3*x^3 + x

# %% [markdown]
# b) Tracer, sur le même graphe, la fonction $\tan(x)$ et ses dévéloppements limités jusqu'à l'ordre 5.

# %%
x = var('x') #définition de la variable x
f = plot(tan(x),x,-5,5, color='black', legend_label="tan(x)") #on fait le graphique du DL de tan(x)
a = plot(taylor(t,x,0,1),x,-5,5, color='blue', legend_label="DL tan(x) ordre 1") #on fait le graphique du DL de tan(x) a l'ordre 1
b = plot(taylor(t,x,0,2),x,-5,5, color='green', legend_label="DL tan(x) ordre 2") #on fait le graphique du DL de tan(x) a l'ordre 2
c = plot(taylor(t,x,0,3),x,-5,5, color='yellow', legend_label="DL tan(x) ordre 3") #on fait le graphique du DL de tan(x) a l'ordre 3
d = plot(taylor(t,x,0,4),x,-5,5, color='orange', legend_label="DL tan(x) ordre 4") #on fait le graphique du DL de tan(x) a l'ordre 4
e = plot(taylor(t,x,0,5),x,-5,5, color='red', legend_label="DL tan(x) ordre 5") #on fait le graphique du DL de tan(x) a l'ordre 5
result = f + a + b + c + d + e #on réunit tous les graphiques pour les afficher en même temps
result.show(ymin=-5, ymax=5) #on affiche sur l'intervalle [-5,5]
# Out:
# Graphics object consisting of 6 graphics primitives

# %% [markdown]
# c) Qu'est-ce qu'il représente le développement limité à l'ordre 1 ?

# %%
print("A l'ordre 1, le DL est la tangente de la fonction. Donc la tangente de tan(x) = x")
# Out:
# A l'ordre 1, le DL est la tangente de la fonction. Donc la tangente de tan(x) = x

# %% [markdown]
# d) Qu'est-ce qu'on peut dire grâce au DL d'ordre 3 au voisinage de 0 ?

# %%
print("On peut en déduire que la fonction tan(x) est impaire")
# Out:
# On peut en déduire que la fonction tan(x) est impaire

# %% [markdown]
# # EXERCICE 5

# %% [markdown]
# Nous voulons déterminer une valeur approchée d'une solution d'équation du type  $f(x)=0$  en utilisant la dichotomie.
#
# a) Définir une fonction `dicho_n(f,a,b,n)` qui prend en entrée une fonction $f$, les extrêmes de l'intervalle $a$ et $b$, et le nombre d'étapes voulues $n$. Elle renvoie en sortie l'encadrement pour la solution approchée par dichotomie, donc les nouvelles valeurs de  $a$  et  $b$ .

# %%
def dicho_n(f,a,b,n):
    for i in range(n): #on initialise une boucle qui fera autants d'itérations que le nombre d'étapes voulues (n)
        c = (a+b)/2 #on définit un nombre c, qui correspond a l'abscisse au centre de a et b
        if f(c) <= 0: 
            a = c #si f(c) est inférieur ou égale a 0, la borne a de départ prend la valeur de c (on réduit donc l'intervalle)
        else:
            b = c #sinon, c'est la borne b qui prend la valeur de c
    return a,b #on retourne les nouvelles bornes

# %% [markdown]
# b) Définir une fonction `dicho_prec(f,a,b,prec)` qui prend en entrée une fonction $f$, les extrêmes de l'intervalle $a$ et $b$, et la précision souhaitée $prec$. Elle renvoie en sortie l'encadrement pour la solution approchée par dichotomie, donc les nouvelles valeurs de $a$ et $b$.

# %%
def dicho_prec(f,a,b,prec):
    while(b-a>=prec): #tant que b-a est supérieur a la valeur de précision voulue
        c = (a+b)/2 #on définit un nombre c, qui correspond a l'abscisse au centre de a et b
        if (f(c) <= 0):
            a = c #si f(c) est inférieur ou égale a 0, la borne a de départ prend la valeur de c (on réduit donc l'intervalle)
        else:
            b = c #sinon, c'est la borne b qui prend la valeur de c
    return a,b #on retourne les nouvelles bornes

# %% [markdown]
# c) Dessiner   $f(x)=x^3+3x^2-1$  sur  $[0,1]$ . Expliquer pourquoi l'équation  $f(x)=0$  admet une unique solution  α  et vérifier que  $α\in[0,1]$ .

# %%
x = var('x')
plot((x^3) + 3*(x^2) -1, x, 0, 1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
print("f(x) est strictement croissante et continue sur [0,1], elle ne s'annule qu'une fois sur cet intervalle, ce qui explique pourquoi il n'y a qu'une seule solution pour f(x)=0")
# Out:
# f(x) est strictement croissante et continue sur [0,1], elle ne s'annule qu'une fois sur cet intervalle, ce qui explique pourquoi il n'y a qu'une seule solution pour f(x)=0

# %% [markdown]
# d) Tester vos fonctions sur  $f(x)=x^3+3x^2-1$, avec $n=10$ et un précision de $10^{-4}$

# %%
f(x) = (x^3) + 3*(x^2) - 1 #on définit la fonction
print("Avec dicho_n")
show(dicho_n(f,0,1,10)) #calcul avec n = 10

print("Avec dicho_prec")
show(dicho_prec(f,0,1,0.0001)) #calcul avec une précision de 10^-4
# Out:
# Avec dicho_n
# (17/32, 545/1024)
# Avec dicho_prec
# (8717/16384, 4359/8192)

# %%
print("En valeur approchée, cela donne:")
print("Avec dicho_n:")
print("(",n(17/32),",", n(545/1024),")") #pour une meilleur visualisation, on affiche la valeur approchée des résultats obtenus avec nos fonctions
print("Avec dicho_prec:")
print("(",n(8717/16384),",", n(4359/8192),")") #pour une meilleur visualisation, on affiche la valeur approchée des résultats obtenus avec nos fonctions
# Out:
# En valeur approchée, cela donne:
# Avec dicho_n:
# ( 0.531250000000000 , 0.532226562500000 )
# Avec dicho_prec:
# ( 0.532043457031250 , 0.532104492187500 )

# %%
x = var('x') #définition de la variable x
find_root((x^3) + 3*(x^2) - 1 == 0, 0, 1) #find_root nous permet de résoudre l'équation f(x) = 0 sur l'intervalle [0,1], pour vérifier les résultats obtenues avec la dichotomie
# Out:
# 0.532088886237956

# %%
print("On remarque que le résultat graphique (question c), nos deux fonctions utilisant la dichotomie, ainsi que la solution de l'équation nous permettent de vérifier la véracité de nos résultats, car ils sont tous très proches. La solution de f(x) = 0 sur [0,1] est donc x environ égal a 0.53")
# Out:
# On remarque que le résultat graphique (question c), nos deux fonctions utilisant la dichotomie, ainsi que la solution de l'équation nous permettent de vérifier la véracité de nos résultats, car ils sont tous très proches. La solution de f(x) = 0 sur [0,1] est donc x environ égal a 0.53
